# %%
import pandas as pd 
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Administrator\DS_AI_Internship\src\day27\canada_per_capita_income.csv")
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
df.isnull().sum()
# Out:
# year                       0
# per capita income (US$)    0
# dtype: int64

# %%
df = df.dropna()

# %%
plt.xlabel('year')
plt.ylabel('per capita income (US$)')
plt.scatter(df['year'], df['per capita income (US$)'], color='black', marker='*')

# %%
plt.plot(df['year'], df['per capita income (US$)'], marker='*')
plt.xlabel('Year')
plt.ylabel('per_capita_income')
plt.title('Per Capita Income Over Years')
plt.show()

# %%
per capita income (US$) = df.per capita income (US$)
per capita income (US$)
# Out:
#   Cell In[23], line 1
#     per capita income (US$) = df.per capita income (US$)
#         ^
# SyntaxError: invalid syntax

# %%
X = df[['year']]   
y = df['per capita income (US$)']
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X, y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([828.46507522])

# %%
reg.intercept_
# Out:
# np.float64(-1632210.7578554575)

# %%
reg.predict([[2020]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %%
new_data=pd.DataFrame([[2020]],columns=['year'])
prediction=reg.predict(new_data)
prediction=np.round(prediction,2)
prediction
# Out:
# array([41288.69])

# %%
new_data=pd.DataFrame([[2023]],columns=['year'])
prediction=reg.predict(new_data)
prediction=np.round(prediction,2)
prediction
# Out:
# array([43774.09])
